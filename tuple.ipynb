# %%
from collections import namedtuple

if __name__ == '__main__':
    n = int(input())                # number of students
    fields = input().split()        # e.g. "ID NAME CLASS MARKS"
    Student = namedtuple('Student', fields)

    total = 0
    for _ in range(n):
        values = input().split()
        student = Student(*values)
        total += float(student.MARKS)

    avg = total / n
    print(f'{avg:.2f}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       9 for _ in range(n):
#      10     values = input().split()
# ---> 11     student = Student(*values)
#      12     total += float(student.MARKS)
#      14 avg = total / n
#
# TypeError: Student.__new__() takes 1 positional argument but 5 were given
