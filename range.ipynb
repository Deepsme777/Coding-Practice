# %%
i = int(input("Enter an value: "))

for i in range(i) :
    print(i + 1 , end = "")
# Out:
# 1234

# %%
i = int(input("Enter an value: "))

for i in range(i) :
    print(i, end = "")
# Out:
# 0123
