# %%
# Reverse an Integer

n = 123

s = str(123)

print(type(s))

s = s[::-1]
s = int(s)
print(type(s))
print(s)
# Out:
# <class 'str'>
# <class 'int'>
# 321

# %%
# for negative values

def Reverse_Number(n) :

    if n < 0 :
        sign = -1

        n = abs(n)
        n = str(n)
        n = n[::-1]
        n = int(n)
        n = n * sign
        return(n)

    else :
        n = str(n)
        n = n[::-1]
        n = int(n)
        return(n)

Reverse_Number(-123)
# Out:
# -321
