# %%
for i in range(10):
    i = i + 1
    print(str(i) + ". Hema kani oru looose")
# Out:
# 1. Hema kani oru looose
# 2. Hema kani oru looose
# 3. Hema kani oru looose
# 4. Hema kani oru looose
# 5. Hema kani oru looose
# 6. Hema kani oru looose
# 7. Hema kani oru looose
# 8. Hema kani oru looose
# 9. Hema kani oru looose
# 10. Hema kani oru looose
